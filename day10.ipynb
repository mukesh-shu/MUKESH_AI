# %%
# !python -m pip install matplotlib
# !python -m pip install opencv-python
# !python -m pip install scikit--image
# !python -m pip install pillow
# Out:
# Requirement already satisfied: matplotlib in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (3.7.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mukesh kumar\appdata\roaming\python\python310\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mukesh kumar\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\mukesh kumar\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.25.1)
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit--image in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (0.21.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (3.1)
# Requirement already satisfied: packaging>=21 in c:\users\mukesh kumar\appdata\roaming\python\python310\site-packages (from scikit--image) (23.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (2.31.1)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (1.25.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (0.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (2023.7.18)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (10.0.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (from scikit--image) (1.11.1)
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pillow in c:\users\mukesh kumar\appdata\local\programs\python\python310\lib\site-packages (10.0.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2 
import skimage
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
# open show and save an image
img1 = plt.imread('robot.jpg')
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
img = cv2.imread('robot1.jpg')
cv2.imshow('Image', img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
img2 = skimage.io.imread('robot1.jpg')
skimage.io.imshow(img2)

# %%
img2
# Out:
# array([[[114,  97,  87],
#         [115,  98,  88],
#         [114, 100,  91],
#         ...,
#         [184, 153, 125],
#         [184, 153, 125],
#         [183, 152, 124]],
#
#        [[114,  97,  87],
#         [115,  98,  88],
#         [114, 100,  91],
#         ...,
#         [183, 152, 124],
#         [183, 152, 124],
#         [183, 152, 124]],
#
#        [[115,  98,  88],
#         [116,  99,  89],
#         [115, 101,  92],
#         ...,
#         [183, 152, 124],
#         [183, 152, 124],
#         [183, 152, 124]],
#
#        ...,
#
#        [[166, 123,  78],
#         [165, 122,  77],
#         [165, 122,  77],
#         ...,
#         [135,  99,  67],
#         [134,  98,  66],
#         [134,  98,  66]],
#
#        [[164, 121,  76],
#         [165, 122,  77],
#         [165, 122,  77],
#         ...,
#         [134,  98,  66],
#         [134,  98,  66],
#         [133,  97,  65]],
#
#        [[164, 121,  76],
#         [164, 121,  76],
#         [165, 122,  77],
#         ...,
#         [134,  98,  66],
#         [133,  97,  65],
#         [133,  97,  65]]], dtype=uint8)
